# %%
# !pip install opencv-python numpy matplotlib

# %%
# !wget https://raw.githubusercontent.com/jairoFarias/ProcessamentoImagem/main/imagens/foto_autoral.jpg
# Out:
# 'wget' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.

# %% [markdown]
# ### Exercício 1
# Carregue uma imagem colorida própria e exiba-a com correção de canais (BGR → RGB).

# %%
import cv2
import matplotlib.pyplot as plt

img_bgr = cv2.imread('foto_autoral.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis('off')

# %% [markdown]
# ## Exercício 2
# Imprima shape, size e dtype

# %%
print("Shape:", img_rgb.shape)
print("Size:", img_rgb.size)
print("Dtype:", img_rgb.dtype)

# %% [markdown]
# ## Exercício 3

# %%
cv2.imwrite("foto_autoral_convertida.jpg", cv2.cvtColor(img_rgb, cv2.COLOR_RGB2BGR))

# %%
h, w, _ = img_rgb.shape
pixel_central = img_rgb[h//2, w//2]
print("Pixel central (R, G, B):", pixel_central)

# %%
img_mod = img_rgb.copy()
img_mod[0:100, 0:100] = [255, 0, 0]

plt.imshow(img_mod)
plt.axis("off")

# %%
roi = img_rgb[100:300, 200:400]

plt.imshow(roi)
plt.axis("off")

# %%
b, g, r = cv2.split(img_rgb)

# %%
plt.imshow(g, cmap="gray")
plt.axis("off")

# %%
img_trocada = cv2.merge((r, g, b))

plt.imshow(img_trocada)
plt.axis("off")

# %%
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)

plt.imshow(img_gray, cmap="gray")
plt.axis("off")

# %%
img_hsv = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2HSV)
s = img_hsv[:, :, 1]

plt.imshow(s, cmap="gray")
plt.axis("off")

# %%
img_brilho = cv2.add(img_gray, 50)

plt.imshow(img_brilho, cmap="gray")
plt.axis("off")

# %%
img2 = cv2.resize(img_rgb, (img_rgb.shape[1], img_rgb.shape[0]))
mesclada = cv2.addWeighted(img_rgb, 0.5, img2, 0.5, 0)

plt.imshow(mesclada)
plt.axis("off")

# %%
negativo = 255 - img_gray

plt.imshow(negativo, cmap="gray")
plt.axis("off")

# %%
mask = np.zeros(img_gray.shape, dtype=np.uint8)
cv2.circle(mask, (w//2, h//2), min(w, h)//4, 255, -1)

resultado = cv2.bitwise_and(img_gray, img_gray, mask=mask)

plt.imshow(resultado, cmap="gray")
plt.axis("off")

# %%
resized = cv2.resize(img_rgb, None, fx=0.3, fy=0.3)
print("Novo shape:", resized.shape)

plt.imshow(resized)
plt.axis("off")

# %%
hist = cv2.calcHist([img_gray], [0], None, [256], [0,256])
print(hist.flatten())

# %%
colors = ('r','g','b')
for i, c in enumerate(colors):
    hist = cv2.calcHist([img_rgb], [i], None, [256], [0,256])
    plt.plot(hist, color=c)

plt.title("Histograma RGB")
plt.show()

# %%
equalizada = cv2.equalizeHist(img_gray)

plt.imshow(equalizada, cmap="gray")
plt.axis("off")

# %%
_, thresh = cv2.threshold(img_gray, 127, 255, cv2.THRESH_BINARY)

plt.imshow(thresh, cmap="gray")
plt.axis("off")
